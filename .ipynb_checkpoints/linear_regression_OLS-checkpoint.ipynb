# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x * 2 - 1) * (x**2 - 2) * (x - 2) + 3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k')
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0, 3).rvs(100)
y = f(x) + stats.norm(0, 0.2).rvs(len(x))
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_tr, y_tr, '--k')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack((np.ones_like(x), x)).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x + p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack((np.ones_like(x), x, x**2)).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2] * pow(x, 2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vander(x, 4)[::,::-1]
p3 = np.linalg.lstsq(M3, y, rcond=None)

# %%
f_lr_3 = lambda x: sum([p3[0][i] * x**i for i in range(1, 4)]) + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vander(x, 5)[::,::-1]
p4 = np.linalg.lstsq(M4, y, rcond=None)

# %%
f_lr_4 = lambda x: sum([p4[0][i] * x**i for i in range(1, 5)]) + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vander(x, 6)[::,::-1]
p5 = np.linalg.lstsq(M5, y, rcond=None)

# %%
f_lr_5 = lambda x: sum([p5[0][i] * x**i for i in range(1, 6)]) + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
y_f_lr_2 = f_lr_2(x_tr)
y_f_lr_3 = f_lr_3(x_tr)
y_f_lr_4 = f_lr_4(x_tr)
y_f_lr_5 = f_lr_5(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_f_lr, y_f_lr_1)
plt.plot(x_f_lr, y_f_lr_2)
plt.plot(x_f_lr, y_f_lr_3)
plt.plot(x_f_lr, y_f_lr_4)
plt.plot(x_f_lr, y_f_lr_5)
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.482
# Dependent Variable: y                AIC:                588.9026
# Date:               2020-04-24 20:42 BIC:                594.1129
# No. Observations:   100              Log-Likelihood:     -292.45
# Df Model:           1                F-statistic:        93.06
# Df Residuals:       98               Prob (F-statistic): 7.08e-16
# R-squared:          0.487            Scale:              20.725
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -2.3412     0.9400   -2.4907   0.0144   -4.2066   -0.4758
# x1         5.5261     0.5729    9.6466   0.0000    4.3893    6.6629
# -----------------------------------------------------------------
# Omnibus:              26.989       Durbin-Watson:          2.356
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       44.173
# Skew:                 1.166        Prob(JB):               0.000
# Kurtosis:             5.272        Condition No.:          4
# =================================================================

# %%
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.769
# Dependent Variable: y                AIC:                509.1893
# Date:               2020-04-24 20:42 BIC:                517.0049
# No. Observations:   100              Log-Likelihood:     -251.59
# Df Model:           2                F-statistic:        165.6
# Df Residuals:       97               Prob (F-statistic): 5.33e-32
# R-squared:          0.773            Scale:              9.2486
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     5.9984     0.9806    6.1172   0.0000     4.0522    7.9446
# x1      -10.4988     1.4970   -7.0134   0.0000   -13.4698   -7.5277
# x2        5.4468     0.4919   11.0728   0.0000     4.4705    6.4232
# -----------------------------------------------------------------
# Omnibus:              1.022        Durbin-Watson:           2.036
# Prob(Omnibus):        0.600        Jarque-Bera (JB):        0.870
# Skew:                 0.228        Prob(JB):                0.647
# Kurtosis:             2.967        Condition No.:           24
# =================================================================

# %%
print(Res3.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.987
# Dependent Variable: y                AIC:                220.8922
# Date:               2020-04-24 20:42 BIC:                231.3129
# No. Observations:   100              Log-Likelihood:     -106.45
# Df Model:           3                F-statistic:        2543.
# Df Residuals:       96               Prob (F-statistic): 2.67e-91
# R-squared:          0.988            Scale:              0.51266
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -3.2980    0.3249  -10.1510  0.0000   -3.9429   -2.6530
# x1         24.7286    0.9352   26.4429  0.0000   22.8723   26.5849
# x2        -24.1050    0.7358  -32.7590  0.0000  -25.5656  -22.6444
# x3          6.6905    0.1645   40.6683  0.0000    6.3639    7.0170
# -----------------------------------------------------------------
# Omnibus:              4.430        Durbin-Watson:           1.858
# Prob(Omnibus):        0.109        Jarque-Bera (JB):        3.833
# Skew:                 0.460        Prob(JB):                0.147
# Kurtosis:             3.268        Condition No.:           165
# =================================================================

# %%
print(Res4.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -35.4258
# Date:               2020-04-24 20:42 BIC:                -22.4000
# No. Observations:   100              Log-Likelihood:     22.713
# Df Model:           4                F-statistic:        2.527e+04
# Df Residuals:       95               Prob (F-statistic): 7.64e-143
# R-squared:          0.999            Scale:              0.039131
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.8102     0.1157    -7.0043   0.0000   -1.0398   -0.5806
# x1         9.5053     0.5158    18.4275   0.0000    8.4812   10.5293
# x2        -1.3656     0.6972    -1.9588   0.0531   -2.7497    0.0184
# x3        -5.3492     0.3560   -15.0260   0.0000   -6.0559   -4.6424
# x4         2.0651     0.0606    34.0987   0.0000    1.9449    2.1853
# ------------------------------------------------------------------
# Omnibus:               0.219        Durbin-Watson:           1.908
# Prob(Omnibus):         0.896        Jarque-Bera (JB):        0.238
# Skew:                  0.107        Prob(JB):                0.888
# Kurtosis:              2.892        Condition No.:           1163
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.

# %%
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -33.4412
# Date:               2020-04-24 20:43 BIC:                -17.8102
# No. Observations:   100              Log-Likelihood:     22.721
# Df Model:           5                F-statistic:        2.001e+04
# Df Residuals:       94               Prob (F-statistic): 1.29e-140
# R-squared:          0.999            Scale:              0.039541
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.8010     0.1390   -5.7647   0.0000   -1.0769   -0.5251
# x1          9.4193     0.8820   10.6793   0.0000    7.6681   11.1706
# x2         -1.1632     1.8213   -0.6386   0.5246   -4.7794    2.4531
# x3         -5.5339     1.5750   -3.5135   0.0007   -8.6612   -2.4066
# x4          2.1366     0.5968    3.5798   0.0005    0.9515    3.3216
# x5         -0.0099     0.0819   -0.1204   0.9044   -0.1724    0.1527
# ------------------------------------------------------------------
# Omnibus:               0.225        Durbin-Watson:           1.905
# Prob(Omnibus):         0.894        Jarque-Bera (JB):        0.219
# Skew:                  0.106        Prob(JB):                0.896
# Kurtosis:              2.912        Condition No.:           8488
# ==================================================================
# * The condition number is large (8e+03). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.482
# Dependent Variable: y                AIC:                588.9026
# Date:               2020-04-24 20:43 BIC:                594.1129
# No. Observations:   100              Log-Likelihood:     -292.45
# Df Model:           1                F-statistic:        93.06
# Df Residuals:       98               Prob (F-statistic): 7.08e-16
# R-squared:          0.487            Scale:              20.725
# ------------------------------------------------------------------
#                Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ------------------------------------------------------------------
# Intercept     -2.3412    0.9400  -2.4907  0.0144  -4.2066  -0.4758
# x              5.5261    0.5729   9.6466  0.0000   4.3893   6.6629
# -----------------------------------------------------------------
# Omnibus:              26.989       Durbin-Watson:          2.356
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       44.173
# Skew:                 1.166        Prob(JB):               0.000
# Kurtosis:             5.272        Condition No.:          4
# =================================================================
