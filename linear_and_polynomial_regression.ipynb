# %% [markdown]
# # Regresja liniowa i wielomianowa

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn import datasets, linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import metrics

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)

# %%
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_tr, y_tr, '--k')
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0, 3).rvs(100)
y = f(x) + stats.norm(0, 0.2).rvs(len(x))
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_tr, y_tr, '--k')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
x = np.vstack(x)
model1 = linear_model.LinearRegression()
model1.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
print(model1.coef_)
print(model1.intercept_)
print(model1.score(x, y))
# Out:
# [7.05732039]
# -3.503691910260775
# 0.5767252845266897

# %%
# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y,  color='black')
plt.plot(x, model1.predict(x), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model2 = make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression())
model2.fit(x, y)
# Out:
# Pipeline(memory=None,
#          steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('linearregression',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model2.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model3 = make_pipeline(PolynomialFeatures(3), linear_model.LinearRegression())
model3.fit(x, y)
# Out:
# Pipeline(memory=None,
#          steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=3, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('linearregression',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model3.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model4 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model4.fit(x, y)

# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model4.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model5 = make_pipeline(PolynomialFeatures(5), linear_model.LinearRegression())
model5.fit(x, y)

# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model5.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.plot(x_plot, model1.predict(x_plot), 'r')
plt.plot(x_plot, model2.predict(x_plot), 'g')
plt.plot(x_plot, model3.predict(x_plot), 'b')
plt.plot(x_plot, model4.predict(x_plot), 'c')
plt.plot(x_plot, model5.predict(x_plot), 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
error1 = np.average( np.abs(model1.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model1.predict(x))))

error2 = np.average( (model1.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model1.predict(x)) ))

error3 = np.median( np.abs(model1.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model1.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model1.predict(x))))
ss_res=np.sum( (y-model1.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error4 = 1-np.var(y - model1.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model1.predict(x)) ))
# Out:
# Mean absolute errors: 4.475768236834945
# Mean absolute errors: 4.475768236834945
# Mean squared error: 29.579005370395834
# Mean squared error: 29.579005370395834
# Median absolute error: 3.298100536460975
# Median absolute error: 3.298100536460975
# R^2: 0.5767252845266897
# R^2: 0.5767252845266897
# Explained variance score: 0.5767252845266897
# Explained variance score: 0.5767252845266897

# %% [markdown]
# # Zadanie
#
# Wylicz powyższe miary dla wszytkich modeli.

# %%
for i in range(1, 6):
    print(f"model{i}")
    print("R^2: {}".format(metrics.r2_score(y, eval(f"model{i}.predict(x)"))))
    print("Explained variance score: {}".format(metrics.explained_variance_score(y, eval(f"model{i}.predict(x)"))))
    print("Median absolute error: {}".format( metrics.median_absolute_error(y, eval(f"model{i}.predict(x)"))))
    print("Mean squared error: {}".format( metrics.mean_squared_error(y, eval(f"model{i}.predict(x)"))))
    print("Median absolute error: {}".format( metrics.median_absolute_error(y, eval(f"model{i}.predict(x)"))))
# Out:
# model1
# R^2: 0.5767252845266897
# Explained variance score: 0.5767252845266897
# Median absolute error: 3.298100536460975
# Mean squared error: 29.579005370395834
# Median absolute error: 3.298100536460975
# model2
# R^2: 0.8218204383449933
# Explained variance score: 0.8218204383449933
# Median absolute error: 2.866993992711563
# Mean squared error: 12.45142697738236
# Median absolute error: 2.866993992711563
# model3
# R^2: 0.9924076007846231
# Explained variance score: 0.9924076007846231
# Median absolute error: 0.5222487900592219
# Mean squared error: 0.5305670500887344
# Median absolute error: 0.5222487900592219
# model4
# R^2: 0.9993577771666673
# Explained variance score: 0.9993577771666673
# Median absolute error: 0.15545563385216044
# Mean squared error: 0.044879393787781705
# Median absolute error: 0.15545563385216044
# model5
# R^2: 0.999359849502149
# Explained variance score: 0.999359849502149
# Median absolute error: 0.1549469225031399
# Mean squared error: 0.044734576202183705
# Median absolute error: 0.1549469225031399
